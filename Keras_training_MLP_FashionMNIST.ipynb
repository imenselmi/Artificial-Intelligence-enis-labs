# %%
# Keras Models
import keras 
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.datasets import fashion_mnist

# Aditional Libs
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD #Stochastic Gradient Descent

# %%
# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.reshape(60000,28,28)
x_test = x_test.reshape(10000,28,28)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2)

x_train = x_train.astype('float32')
x_valid = x_valid.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_valid /= 255
x_test /= 255

x_train = x_train.reshape(len(x_train),28,28)
x_test = x_test.reshape(10000,28,28)
x_valid = x_valid.reshape(len(x_valid),28,28)

#print(x_train.shape[0], 'train samples')
#print(x_valid.shape[0], 'valid samples')
#print(x_test.shape[0], 'test samples')

y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test = to_categorical(y_test, 10)

# %%
# Model is the MLP network that we want to create
model = Sequential()
model.add(Flatten(input_shape=(28,28)))#784
model.add(Dense(256, activation='tanh', kernel_initializer = 'he_normal' ,input_shape=(28*28,)))
model.add(Dropout(0.4))
model.add(Dense(128, activation='tanh', kernel_initializer = 'he_normal'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='tanh', kernel_initializer = 'he_normal'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax', kernel_initializer = 'he_normal'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               12900
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 247,766
# Trainable params: 247,766
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = SGD(learning_rate=0.01, momentum=0.975, decay=2e-06, nesterov=True)
model.compile(loss='categorical_crossentropy',
			  optimizer=optimizer,
			  metrics=['accuracy'])

history = model.fit(x_train, y_train,
					batch_size=64,
					epochs=100,
					verbose=2,
					validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 750/750 - 4s - loss: 0.7773 - accuracy: 0.7183 - val_loss: 0.4885 - val_accuracy: 0.8299
# Epoch 2/100
# 750/750 - 3s - loss: 0.5986 - accuracy: 0.7912 - val_loss: 0.4516 - val_accuracy: 0.8456
# Epoch 3/100
# 750/750 - 3s - loss: 0.5573 - accuracy: 0.8081 - val_loss: 0.4506 - val_accuracy: 0.8459
# Epoch 4/100
# 750/750 - 3s - loss: 0.5382 - accuracy: 0.8152 - val_loss: 0.4460 - val_accuracy: 0.8457
# Epoch 5/100
# 750/750 - 3s - loss: 0.5176 - accuracy: 0.8235 - val_loss: 0.4142 - val_accuracy: 0.8572
# Epoch 6/100
# 750/750 - 3s - loss: 0.5112 - accuracy: 0.8259 - val_loss: 0.4334 - val_accuracy: 0.8509
# Epoch 7/100
# 750/750 - 3s - loss: 0.4978 - accuracy: 0.8306 - val_loss: 0.4063 - val_accuracy: 0.8574
# Epoch 8/100
# 750/750 - 3s - loss: 0.4955 - accuracy: 0.8320 - val_loss: 0.4276 - val_accuracy: 0.8572
# Epoch 9/100
# 750/750 - 3s - loss: 0.4831 - accuracy: 0.8365 - val_loss: 0.3952 - val_accuracy: 0.8666
# Epoch 10/100
# 750/750 - 3s - loss: 0.4811 - accuracy: 0.8359 - val_loss: 0.4129 - val_accuracy: 0.8577
# Epoch 11/100
# 750/750 - 3s - loss: 0.4703 - accuracy: 0.8407 - val_loss: 0.3984 - val_accuracy: 0.8607
# Epoch 12/100
# 750/750 - 3s - loss: 0.4671 - accuracy: 0.8400 - val_loss: 0.3921 - val_accuracy: 0.8663
# Epoch 13/100
# 750/750 - 3s - loss: 0.4627 - accuracy: 0.8428 - val_loss: 0.4066 - val_accuracy: 0.8668
# Epoch 14/100
# 750/750 - 3s - loss: 0.4549 - accuracy: 0.8447 - val_loss: 0.4050 - val_accuracy: 0.8650
# Epoch 15/100
# 750/750 - 3s - loss: 0.4581 - accuracy: 0.8441 - val_loss: 0.3808 - val_accuracy: 0.8727
# Epoch 16/100
# 750/750 - 3s - loss: 0.4544 - accuracy: 0.8456 - val_loss: 0.3765 - val_accuracy: 0.8692
# Epoch 17/100
# 750/750 - 3s - loss: 0.4503 - accuracy: 0.8463 - val_loss: 0.3837 - val_accuracy: 0.8731
# Epoch 18/100
# 750/750 - 3s - loss: 0.4439 - accuracy: 0.8497 - val_loss: 0.3907 - val_accuracy: 0.8673
# Epoch 19/100
# 750/750 - 3s - loss: 0.4409 - accuracy: 0.8516 - val_loss: 0.3781 - val_accuracy: 0.8748
# Epoch 20/100
# 750/750 - 3s - loss: 0.4349 - accuracy: 0.8521 - val_loss: 0.3898 - val_accuracy: 0.8719
# Epoch 21/100
# 750/750 - 3s - loss: 0.4353 - accuracy: 0.8511 - val_loss: 0.3748 - val_accuracy: 0.8738
# Epoch 22/100
# 750/750 - 3s - loss: 0.4313 - accuracy: 0.8524 - val_loss: 0.3773 - val_accuracy: 0.8722
# Epoch 23/100
# 750/750 - 3s - loss: 0.4275 - accuracy: 0.8551 - val_loss: 0.3842 - val_accuracy: 0.8727
# Epoch 24/100
# 750/750 - 3s - loss: 0.4278 - accuracy: 0.8549 - val_loss: 0.3772 - val_accuracy: 0.8742
# Epoch 25/100
# 750/750 - 3s - loss: 0.4227 - accuracy: 0.8570 - val_loss: 0.3907 - val_accuracy: 0.8666
# Epoch 26/100
# 750/750 - 3s - loss: 0.4195 - accuracy: 0.8568 - val_loss: 0.3713 - val_accuracy: 0.8763
# Epoch 27/100
# 750/750 - 3s - loss: 0.4210 - accuracy: 0.8555 - val_loss: 0.3913 - val_accuracy: 0.8726
# Epoch 28/100
# 750/750 - 3s - loss: 0.4182 - accuracy: 0.8571 - val_loss: 0.3848 - val_accuracy: 0.8723
# Epoch 29/100
# 750/750 - 3s - loss: 0.4122 - accuracy: 0.8595 - val_loss: 0.3642 - val_accuracy: 0.8711
# Epoch 30/100
# 750/750 - 3s - loss: 0.4166 - accuracy: 0.8591 - val_loss: 0.3718 - val_accuracy: 0.8774
# Epoch 31/100
# 750/750 - 3s - loss: 0.4129 - accuracy: 0.8589 - val_loss: 0.3711 - val_accuracy: 0.8748
# Epoch 32/100
# 750/750 - 3s - loss: 0.4102 - accuracy: 0.8598 - val_loss: 0.3781 - val_accuracy: 0.8746
# Epoch 33/100
# 750/750 - 3s - loss: 0.4106 - accuracy: 0.8612 - val_loss: 0.3804 - val_accuracy: 0.8688
# Epoch 34/100
# 750/750 - 3s - loss: 0.4112 - accuracy: 0.8601 - val_loss: 0.3872 - val_accuracy: 0.8760
# Epoch 35/100
# 750/750 - 3s - loss: 0.4062 - accuracy: 0.8617 - val_loss: 0.3569 - val_accuracy: 0.8776
# Epoch 36/100
# 750/750 - 3s - loss: 0.3999 - accuracy: 0.8640 - val_loss: 0.3722 - val_accuracy: 0.8757
# Epoch 37/100
# 750/750 - 3s - loss: 0.4033 - accuracy: 0.8632 - val_loss: 0.3532 - val_accuracy: 0.8826
# Epoch 38/100
# 750/750 - 3s - loss: 0.4001 - accuracy: 0.8634 - val_loss: 0.3524 - val_accuracy: 0.8800
# Epoch 39/100
# 750/750 - 3s - loss: 0.4028 - accuracy: 0.8624 - val_loss: 0.3819 - val_accuracy: 0.8729
# Epoch 40/100
# 750/750 - 3s - loss: 0.3978 - accuracy: 0.8644 - val_loss: 0.3730 - val_accuracy: 0.8729
# Epoch 41/100
# 750/750 - 3s - loss: 0.3987 - accuracy: 0.8651 - val_loss: 0.3649 - val_accuracy: 0.8797
# Epoch 42/100
# 750/750 - 3s - loss: 0.3976 - accuracy: 0.8660 - val_loss: 0.3642 - val_accuracy: 0.8773
# Epoch 43/100
# 750/750 - 3s - loss: 0.4016 - accuracy: 0.8621 - val_loss: 0.3678 - val_accuracy: 0.8757
# Epoch 44/100
# 750/750 - 3s - loss: 0.3999 - accuracy: 0.8636 - val_loss: 0.3885 - val_accuracy: 0.8745
# Epoch 45/100
# 750/750 - 3s - loss: 0.4028 - accuracy: 0.8618 - val_loss: 0.3580 - val_accuracy: 0.8792
# Epoch 46/100
# 750/750 - 3s - loss: 0.3931 - accuracy: 0.8660 - val_loss: 0.3673 - val_accuracy: 0.8801
# Epoch 47/100
# 750/750 - 3s - loss: 0.3958 - accuracy: 0.8640 - val_loss: 0.3564 - val_accuracy: 0.8808
# Epoch 48/100
# 750/750 - 3s - loss: 0.3906 - accuracy: 0.8656 - val_loss: 0.3494 - val_accuracy: 0.8811
# Epoch 49/100
# 750/750 - 3s - loss: 0.3895 - accuracy: 0.8660 - val_loss: 0.3550 - val_accuracy: 0.8793
# Epoch 50/100
# 750/750 - 3s - loss: 0.3857 - accuracy: 0.8674 - val_loss: 0.3647 - val_accuracy: 0.8813
# Epoch 51/100
# 750/750 - 3s - loss: 0.3830 - accuracy: 0.8690 - val_loss: 0.3424 - val_accuracy: 0.8833
# Epoch 52/100
# 750/750 - 3s - loss: 0.3776 - accuracy: 0.8708 - val_loss: 0.3495 - val_accuracy: 0.8776
# Epoch 53/100
# 750/750 - 3s - loss: 0.3813 - accuracy: 0.8708 - val_loss: 0.3501 - val_accuracy: 0.8852
# Epoch 54/100
# 750/750 - 3s - loss: 0.3899 - accuracy: 0.8668 - val_loss: 0.3617 - val_accuracy: 0.8786
# Epoch 55/100
# 750/750 - 3s - loss: 0.3873 - accuracy: 0.8684 - val_loss: 0.3604 - val_accuracy: 0.8791
# Epoch 56/100
# 750/750 - 3s - loss: 0.3764 - accuracy: 0.8707 - val_loss: 0.3476 - val_accuracy: 0.8862
# Epoch 57/100
# 750/750 - 3s - loss: 0.3839 - accuracy: 0.8690 - val_loss: 0.3569 - val_accuracy: 0.8824
# Epoch 58/100
# 750/750 - 3s - loss: 0.3822 - accuracy: 0.8708 - val_loss: 0.3588 - val_accuracy: 0.8832
# Epoch 59/100
# 750/750 - 3s - loss: 0.3778 - accuracy: 0.8725 - val_loss: 0.3620 - val_accuracy: 0.8773
# Epoch 60/100
# 750/750 - 3s - loss: 0.3775 - accuracy: 0.8721 - val_loss: 0.3732 - val_accuracy: 0.8783
# Epoch 61/100
# 750/750 - 3s - loss: 0.3791 - accuracy: 0.8704 - val_loss: 0.3618 - val_accuracy: 0.8801
# Epoch 62/100
# 750/750 - 3s - loss: 0.3713 - accuracy: 0.8726 - val_loss: 0.3717 - val_accuracy: 0.8790
# Epoch 63/100
# 750/750 - 3s - loss: 0.3728 - accuracy: 0.8724 - val_loss: 0.3619 - val_accuracy: 0.8805
# Epoch 64/100
# 750/750 - 3s - loss: 0.3707 - accuracy: 0.8725 - val_loss: 0.3600 - val_accuracy: 0.8802
# Epoch 65/100
# 750/750 - 3s - loss: 0.3680 - accuracy: 0.8742 - val_loss: 0.3633 - val_accuracy: 0.8867
# Epoch 66/100
# 750/750 - 3s - loss: 0.3682 - accuracy: 0.8770 - val_loss: 0.3634 - val_accuracy: 0.8817
# Epoch 67/100
# 750/750 - 3s - loss: 0.3695 - accuracy: 0.8723 - val_loss: 0.3589 - val_accuracy: 0.8759
# Epoch 68/100
# 750/750 - 3s - loss: 0.3691 - accuracy: 0.8741 - val_loss: 0.3652 - val_accuracy: 0.8841
# Epoch 69/100
# 750/750 - 3s - loss: 0.3706 - accuracy: 0.8733 - val_loss: 0.3619 - val_accuracy: 0.8818
# Epoch 70/100
# 750/750 - 3s - loss: 0.3727 - accuracy: 0.8720 - val_loss: 0.3581 - val_accuracy: 0.8792
# Epoch 71/100
# 750/750 - 3s - loss: 0.3646 - accuracy: 0.8753 - val_loss: 0.3637 - val_accuracy: 0.8791
# Epoch 72/100
# 750/750 - 3s - loss: 0.3649 - accuracy: 0.8752 - val_loss: 0.3532 - val_accuracy: 0.8780
# Epoch 73/100
# 750/750 - 3s - loss: 0.3657 - accuracy: 0.8737 - val_loss: 0.3602 - val_accuracy: 0.8812
# Epoch 74/100
# 750/750 - 3s - loss: 0.3669 - accuracy: 0.8750 - val_loss: 0.3478 - val_accuracy: 0.8858
# Epoch 75/100
# 750/750 - 3s - loss: 0.3702 - accuracy: 0.8725 - val_loss: 0.3473 - val_accuracy: 0.8875
# Epoch 76/100
# 750/750 - 3s - loss: 0.3569 - accuracy: 0.8790 - val_loss: 0.3515 - val_accuracy: 0.8844
# Epoch 77/100
# 750/750 - 3s - loss: 0.3636 - accuracy: 0.8756 - val_loss: 0.3578 - val_accuracy: 0.8878
# Epoch 78/100
# 750/750 - 3s - loss: 0.3607 - accuracy: 0.8772 - val_loss: 0.3719 - val_accuracy: 0.8827
# Epoch 79/100
# 750/750 - 3s - loss: 0.3646 - accuracy: 0.8761 - val_loss: 0.3508 - val_accuracy: 0.8861
# Epoch 80/100
# 750/750 - 3s - loss: 0.3599 - accuracy: 0.8782 - val_loss: 0.3587 - val_accuracy: 0.8827
# Epoch 81/100
# 750/750 - 3s - loss: 0.3618 - accuracy: 0.8769 - val_loss: 0.3407 - val_accuracy: 0.8880
# Epoch 82/100
# 750/750 - 3s - loss: 0.3587 - accuracy: 0.8777 - val_loss: 0.3591 - val_accuracy: 0.8831
# Epoch 83/100
# 750/750 - 3s - loss: 0.3520 - accuracy: 0.8795 - val_loss: 0.3482 - val_accuracy: 0.8879
# Epoch 84/100
# 750/750 - 3s - loss: 0.3567 - accuracy: 0.8789 - val_loss: 0.3523 - val_accuracy: 0.8848
# Epoch 85/100
# 750/750 - 3s - loss: 0.3519 - accuracy: 0.8794 - val_loss: 0.3618 - val_accuracy: 0.8836
# Epoch 86/100
# 750/750 - 3s - loss: 0.3550 - accuracy: 0.8782 - val_loss: 0.3544 - val_accuracy: 0.8818
# Epoch 87/100
# 750/750 - 3s - loss: 0.3532 - accuracy: 0.8794 - val_loss: 0.3604 - val_accuracy: 0.8824
# Epoch 88/100
# 750/750 - 3s - loss: 0.3517 - accuracy: 0.8792 - val_loss: 0.3437 - val_accuracy: 0.8855
# Epoch 89/100
# 750/750 - 3s - loss: 0.3541 - accuracy: 0.8773 - val_loss: 0.3481 - val_accuracy: 0.8860
# Epoch 90/100
# 750/750 - 3s - loss: 0.3482 - accuracy: 0.8795 - val_loss: 0.3498 - val_accuracy: 0.8851
# Epoch 91/100
# 750/750 - 3s - loss: 0.3495 - accuracy: 0.8802 - val_loss: 0.3454 - val_accuracy: 0.8855
# Epoch 92/100
# 750/750 - 3s - loss: 0.3487 - accuracy: 0.8806 - val_loss: 0.3627 - val_accuracy: 0.8855
# Epoch 93/100
# 750/750 - 3s - loss: 0.3455 - accuracy: 0.8816 - val_loss: 0.3480 - val_accuracy: 0.8886
# Epoch 94/100
# 750/750 - 3s - loss: 0.3494 - accuracy: 0.8801 - val_loss: 0.3321 - val_accuracy: 0.8899
# Epoch 95/100
# 750/750 - 3s - loss: 0.3474 - accuracy: 0.8806 - val_loss: 0.3496 - val_accuracy: 0.8875
# Epoch 96/100
# 750/750 - 3s - loss: 0.3442 - accuracy: 0.8820 - val_loss: 0.3686 - val_accuracy: 0.8849
# Epoch 97/100
# 750/750 - 3s - loss: 0.3435 - accuracy: 0.8829 - val_loss: 0.3434 - val_accuracy: 0.8882
# Epoch 98/100
# 750/750 - 3s - loss: 0.3494 - accuracy: 0.8792 - val_loss: 0.3508 - val_accuracy: 0.8844
# Epoch 99/100
# 750/750 - 3s - loss: 0.3454 - accuracy: 0.8811 - val_loss: 0.3658 - val_accuracy: 0.8795
# Epoch 100/100
# 750/750 - 3s - loss: 0.3471 - accuracy: 0.8807 - val_loss: 0.3617 - val_accuracy: 0.8827

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test top 1 accuracy:', score[1])
# Out:
# Test loss: 0.41565799713134766
# Test top 1 accuracy: 0.870199978351593
